# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/sevketugurel/Desktop/ForbesVeriAnalizi/forbes_2022_billionaires.csv")

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
df.shape
# Out:
# (2668, 22)

# %%
df.columns
# Out:
# Index(['rank', 'personName', 'age', 'finalWorth', 'year', 'month', 'category',
#        'source', 'country', 'state', 'city', 'countryOfCitizenship',
#        'organization', 'selfMade', 'gender', 'birthDate', 'title',
#        'philanthropyScore', 'residenceMsa', 'numberOfSiblings', 'bio',
#        'about'],
#       dtype='object')

# %%
df = df.loc[:,["rank","personName", "age", "finalWorth", "category",'country', 'gender']]

# %%
df.head()
# Out:
#    rank                personName   age  finalWorth               category  \
# 0     1                 Elon Musk  50.0    219000.0             Automotive
# 1     2                Jeff Bezos  58.0    171000.0             Technology
# 2     3  Bernard Arnault & family  73.0    158000.0       Fashion & Retail
# 3     4                Bill Gates  66.0    129000.0             Technology
# 4     5            Warren Buffett  91.0    118000.0  Finance & Investments
#
#          country gender
# 0  United States      M
# 1  United States      M
# 2         France      M
# 3  United States      M
# 4  United States      M

# %%
df = df.rename(columns={"rank":"Sıra", "personName":"İsim","age":"Yaş","finalWorth":"Servet", "category":"Kategori", "country":"Ülke", "gender":"Cinsiyet"})

# %%
df.head()
# Out:
#    Sıra                      İsim   Yaş    Servet               Kategori  \
# 0     1                 Elon Musk  50.0  219000.0             Automotive
# 1     2                Jeff Bezos  58.0  171000.0             Technology
# 2     3  Bernard Arnault & family  73.0  158000.0       Fashion & Retail
# 3     4                Bill Gates  66.0  129000.0             Technology
# 4     5            Warren Buffett  91.0  118000.0  Finance & Investments
#
#             Ülke Cinsiyet
# 0  United States        M
# 1  United States        M
# 2         France        M
# 3  United States        M
# 4  United States        M

# %%
df = df.set_index("Sıra")

# %%
df.head()
# Out:
#                           İsim   Yaş    Servet               Kategori  \
# Sıra
# 1                    Elon Musk  50.0  219000.0             Automotive
# 2                   Jeff Bezos  58.0  171000.0             Technology
# 3     Bernard Arnault & family  73.0  158000.0       Fashion & Retail
# 4                   Bill Gates  66.0  129000.0             Technology
# 5               Warren Buffett  91.0  118000.0  Finance & Investments
#
#                Ülke Cinsiyet
# Sıra
# 1     United States        M
# 2     United States        M
# 3            France        M
# 4     United States        M
# 5     United States        M

# %%
df.dtypes
# Out:
# İsim         object
# Yaş         float64
# Servet      float64
# Kategori     object
# Ülke         object
# Cinsiyet     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# İsim         0
# Yaş         86
# Servet       0
# Kategori     0
# Ülke        13
# Cinsiyet    16
# dtype: int64

# %%
df.dropna(inplace=True) # Veri setindeki nullları temizliyoruz

# %%
df.shape
# Out:
# (2568, 6)

# %%
df["Cinsiyet"].value_counts(normalize=True)
# Out:
# M    0.888629
# F    0.111371
# Name: Cinsiyet, dtype: float64

# %%
# Türkiyedeki zenginlerin cinsiyet dağılımı
df[df["Ülke"]=="Turkey"].Cinsiyet.value_counts(normalize=True)
# Out:
# M    0.826087
# F    0.173913
# Name: Cinsiyet, dtype: float64

# %%
# Hangi ülkeler olduğunu öğrendik
df["Ülke"].unique()
# Out:
# array(['United States', 'France', 'India', 'Mexico', 'China', 'Singapore',
#        'Spain', 'Canada', 'Germany', 'Switzerland', 'Belgium',
#        'Hong Kong', 'United Kingdom', 'Australia', 'Austria', 'Italy',
#        'Japan', 'Bahamas', 'Indonesia', 'Chile', 'Russia', 'Sweden',
#        'Czechia', 'Monaco', 'United Arab Emirates', 'Nigeria', 'Denmark',
#        'Thailand', 'Malaysia', 'Brazil', 'Colombia', 'New Zealand',
#        'South Korea', 'South Africa', 'Philippines', 'Egypt', 'Taiwan',
#        'Israel', 'Vietnam', 'Poland', 'Norway', 'Cayman Islands',
#        'Netherlands', 'Eswatini (Swaziland)', 'Peru', 'Algeria',
#        'Kazakhstan', 'Georgia', 'Portugal', 'British Virgin Islands',
#        'Turkey', 'Finland', 'Ukraine', 'Ireland', 'Bermuda', 'Lebanon',
#        'Argentina', 'Cambodia', 'Oman', 'Guernsey', 'Liechtenstein',
#        'Turks and Caicos Islands', 'Qatar', 'Morocco', 'Uruguay',
#        'Slovakia', 'Romania', 'Nepal', 'Tanzania', 'Bahrain', 'Greece',
# ...

# %%
df[df["Ülke"]=="Canada"].Cinsiyet.value_counts(normalize=True)
# Out:
# M    0.952381
# F    0.047619
# Name: Cinsiyet, dtype: float64

# %%
# cinsiyete göre grupladık
df_cinsiyet = df.groupby(["Cinsiyet"])

# %%
# grubun yaş ortalamalarını buluyoruz yani cinsiyetlerin yaş ortalamasını bulmuş olduk
df_cinsiyet["Yaş"].mean()
# Out:
# Cinsiyet
# F    62.937063
# M    64.409290
# Name: Yaş, dtype: float64

# %%
import seaborn as sns
sns.set_theme()
sns.set(rc = {"figure.dpi":300})
# Uyarı mesajı almamak için görmezden geldik
import warnings
warnings.filterwarnings("ignore")

# %%
# en zenginlerin sayısının cinsiyete göre dağılımı
df_cinsiyet.size().plot(kind="bar")
# Out:
# <Axes: xlabel='Cinsiyet'>

# %%
# En zenginlerin servetleri ve sıralaması tablosu
sns.barplot(y = df["İsim"][:10], x = df["Servet"][:10])
# Out:
# <Axes: xlabel='Servet', ylabel='İsim'>

# %%
# Listede kaç tane ülke olduğunu öğrenelim
len(df["Ülke"].unique())
# Out:
# 73

# %%
 df_ulke = df.groupby("Ülke")

# %%
df_ulke_sayısı = pd.DataFrame(df_ulke.size().sort_values(ascending=False), columns=["Sayı"])

# %%
df_ulke_sayısı.head()
# Out:
#                 Sayı
# Ülke
# United States    742
# China            546
# India            154
# Germany           94
# United Kingdom    81

# %%
#En çok zengin bulunduran ülkeler tablosu
sns.barplot(x = df_ulke_sayısı["Sayı"][:10], y = df_ulke_sayısı.index[:10])
# Out:
# <Axes: xlabel='Sayı', ylabel='Ülke'>

# %%
#Türkiyedeki en zenginler
df_turkiye = df[df["Ülke"]=="Turkey"]

# %%
#Türkiyedeki en zenginler adedi
df_turkiye["İsim"].count()
# Out:
# 23

# %%
df_turkiye.head(10)
# Out:
#                      İsim   Yaş  Servet                    Kategori    Ülke  \
# Sıra
# 601           Murat Ulker  63.0  4700.0             Food & Beverage  Turkey
# 1292    Ferit Faik Sahenk  58.0  2400.0                 Diversified  Turkey
# 1341         Erman Ilicak  54.0  2300.0  Construction & Engineering  Turkey
# 1397         Filiz Sahenk  55.0  2200.0                 Diversified  Turkey
# 1579       Sezai Bacaksiz  72.0  1900.0                 Diversified  Turkey
# 1579        Nihat Ozdemir  72.0  1900.0                 Diversified  Turkey
# 1645    Ibrahim Erdemoglu  59.0  1800.0               Manufacturing  Turkey
# 1818  Semahat Sevim Arsel  93.0  1600.0                 Diversified  Turkey
# 1929  Hamdi Akin & family  67.0  1500.0                 Diversified  Turkey
# 1929          Ahmet Calik  64.0  1500.0                 Diversified  Turkey
#
#      Cinsiyet
# Sıra
# 601         M
# 1292        M
# 1341        M
# 1397        F
# 1579        M
# 1579        M
# ...

# %%
sns.barplot(y= df_turkiye["İsim"][:10],x = df_turkiye["Servet"][:10])
# Out:
# <Axes: xlabel='Servet', ylabel='İsim'>

# %%
df["Kategori"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion & Retail',
#        'Finance & Investments', 'Diversified', 'Media & Entertainment',
#        'Telecom', 'Food & Beverage', 'Logistics', 'Real Estate',
#        'Metals & Mining', 'Manufacturing', 'Gambling & Casinos',
#        'Healthcare', 'Service', 'Energy', 'Construction & Engineering',
#        'Sports'], dtype=object)

# %%
# Boşlukları kaldırdık ve & -> _ şeklinde bir değiştirme yaptık
df["Kategori"] = df["Kategori"].apply(lambda x:x.replace(" ","")). apply(lambda x:x.replace("&","_"))

# %%
df["Kategori"].unique()
# Out:
# array(['Automotive', 'Technology', 'Fashion_Retail',
#        'Finance_Investments', 'Diversified', 'Media_Entertainment',
#        'Telecom', 'Food_Beverage', 'Logistics', 'RealEstate',
#        'Metals_Mining', 'Manufacturing', 'Gambling_Casinos', 'Healthcare',
#        'Service', 'Energy', 'Construction_Engineering', 'Sports'],
#       dtype=object)

# %%
df_kategori = df.groupby("Kategori").size()

# %%
df_kategori.head()
# Out:
# Kategori
# Automotive                   66
# Construction_Engineering     45
# Diversified                 174
# Energy                       93
# Fashion_Retail              238
# dtype: int64

# %%
df_kategori = df_kategori.to_frame()

# %%
df_kategori.head()
# Out:
#                             0
# Kategori
# Automotive                 66
# Construction_Engineering   45
# Diversified               174
# Energy                     93
# Fashion_Retail            238

# %%
df_kategori = df_kategori.rename(columns={0:"Sayı"}).sort_values(by="Sayı", ascending=False)

# %%
df_kategori.head()
# Out:
#                      Sayı
# Kategori
# Finance_Investments   381
# Technology            332
# Manufacturing         319
# Fashion_Retail        238
# Healthcare            209

# %%
#En fazla kategoride olan zengin sayısı
sns.barplot(x = df_kategori["Sayı"][:10], y= df_kategori.index[:10])
# Out:
# <Axes: xlabel='Sayı', ylabel='Kategori'>

# %%
sns.scatterplot(x=df["Yaş"],y= df["Servet"])
# Out:
# <Axes: xlabel='Yaş', ylabel='Servet'>

# %%
sns.histplot(df["Yaş"])
# Out:
# <Axes: xlabel='Yaş', ylabel='Count'>

# %%
df_yas = df.sort_values(by="Yaş",ascending=True)

# %%
df_yas.head()
# Out:
#                     İsim   Yaş  Servet             Kategori           Ülke  \
# Sıra
# 2190  Alexandra Andresen  25.0  1300.0          Diversified         Norway
# 1929         Wang Zelong  25.0  1500.0        Metals_Mining          China
# 1929    Pedro Franceschi  25.0  1500.0  Finance_Investments  United States
# 1929   Henrique Dubugras  26.0  1500.0  Finance_Investments  United States
# 2190  Katharina Andresen  26.0  1300.0          Diversified         Norway
#
#      Cinsiyet
# Sıra
# 2190        F
# 1929        M
# 1929        M
# 1929        M
# 2190        F

# %%
#Listedeki en genç 10 kişinin grafiği
sns.barplot(y = df_yas["İsim"][:10], x=df_yas["Yaş"][:10])
# Out:
# <Axes: xlabel='Yaş', ylabel='İsim'>
